# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
ins = pd.read_excel('/content/top 10 vis.xlsx')

# %%
print(ins)
# Out:
#                                              UNI  Count
# 0                         UniversityofPittsburgh     49
# 1                         UniversityofCalifornia     27
# 2        MarshfieldClinicResearchInstitute Count     24
# 3            HarvardSchoolofDentalMedicine Count     18
# 4           UniversityofTexasHealthScienceCenter     17
# 5                  HealthPartnersInstitute Count     12
# 6                        IndianaUniversity Count     12
# 7                               MayoClinic Count     12
# 8  UniversityofTexasHealthScienceCenteratHouston     12
# 9                 OregonHealth&ScienceUniversity     11

# %%
ins.head()
# Out:
#                                        UNI  Count
# 0                   UniversityofPittsburgh     49
# 1                   UniversityofCalifornia     27
# 2  MarshfieldClinicResearchInstitute Count     24
# 3      HarvardSchoolofDentalMedicine Count     18
# 4     UniversityofTexasHealthScienceCenter     17

# %%
sns.barplot(ins['Count'], ins['UNI'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
