# %% [markdown]
# <a href="https://colab.research.google.com/github/maddisurekha1234/Dental_Informatics_Project/blob/main/Articles_Citation_Journals_Analysis_latest.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Mounting the drive for collecting data from csv files 
# Load the Drive helper and mount
from google.colab import drive

# This will prompt for authorization.
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
ls "/content/drive/My Drive/Latest_files_Jan26/"
# Out:
# Article0.json    Article33.json  Article70.json
# Article100.json  Article34.json  Article71.json
# Article101.json  Article35.json  Article72.json
# Article102.json  Article36.json  Article73.json
# Article103.json  Article37.json  Article74.json
# Article104.json  Article38.json  Article75.json
# Article105.json  Article39.json  Article76.json
# Article106.json  Article3.json   Article77.json
# Article107.json  Article40.json  Article78.json
# Article108.json  Article41.json  Article79.json
# Article109.json  Article42.json  Article7.json
# Article10.json   Article43.json  Article80.json
# Article110.json  Article44.json  Article81.json
# Article111.json  Article45.json  Article82.json
# Article112.json  Article46.json  Article83.json
# Article113.json  Article47.json  Article84.json
# Article114.json  Article48.json  Article85.json
# Article11.json   Article49.json  Article86.json
# Article12.json   Article4.json   Article87.json
# Article13.json   Article50.json  Article88.json
# Article14.json   Article51.json  Article89.json
# Article15.json   Article52.json  Article8.json
# Article16.json   Article53.json  Article90.json
# Article17.json   Article54.json  Article91.json
# Article18.json   Article55.json  Article92.json
# Article19.json   Article56.json  Article93.json
# Article1.json    Article57.json  Article94.json
# Article20.json   Article58.json  Article95.json
# Article21.json   Article59.json  Article96.json
# Article22.json   Article5.json   Article97.json
# Article23.json   Article60.json  Article98.json
# Article24.json   Article61.json  Article99.json
# Article25.json   Article62.json  Article9.json
# Article26.json   Article63.json  Article_information_Final.csv
# Article27.json   Article64.json  Article_information_jan26.csv
# Article28.json   Article65.json  author_info_withdoi.csv
# Article29.json   Article66.json  author_names.csv
# Article2.json    Article67.json  Latest_Article_info_jan26_pubmed.csv
# Article30.json   Article68.json  Latest_files_Jan26_pubmed/
# Article31.json   Article69.json  Reference_articles.csv
# Article32.json   Article6.json   table4.csv

# %%
#collection of citation information from all the json files and appending it to a dataframe and generating csv file.
import json
import pandas as pd
from pandas import DataFrame
article_id = []
citingpaperId = []
citingdoi = []
citingtitle = []
citingvenue = []
citingyear = []
citingintent = []
citinginfluential = []
authornamelist= []
authoridlist = []
authorurllist = []
for i in range(115):
  f = open('/content/drive/MyDrive/Latest_files_Jan26/Article' + str(i) + '.json')
  data = json.load(f)
  print("****** i",i)
  article_data = data['doi']
  for value in data['citations']:
    paperId = value['paperId']
    doi = value['doi']
    title = value['title']
    venue = value['venue']
    year = value['year']
    intent = value['intent']
    isInfluential = value['isInfluential']
    for i in value['authors']:
     citingpaperId.append(paperId)
     article_id.append(article_data)
     citingdoi.append(doi)
     citingtitle.append(title)
     citingvenue.append(venue)
     citingyear.append(year)
     citingintent.append(intent)
     citinginfluential.append(isInfluential) 
     authorname = i['name']
     authornamelist.append(authorname)
     authorid = i['authorId']
     authoridlist.append(authorid)
    #  authorurl= i['url']
    #  authorurllist.append(authorurl) 
a = {'article_id': article_id,'authorid': authoridlist,'authorname':authornamelist,'authorurl': authorurllist, 'paperId' : citingpaperId ,'doi' : citingdoi ,'title' : citingtitle ,
     'citing_venue' :citingvenue, 'year': citingyear,
     'intent' : citingintent,'isInfluential' : citinginfluential}
df = pd.DataFrame.from_dict(a, orient='index')
df1 = df.transpose()
df1['intent'] = df1['intent'].apply(lambda x : ' '.join(map(str, x)))
df1.to_csv('table3.csv', columns = a)
df1
# Out:
# ****** i 0
# ****** i 1
# ****** i 2
# ****** i 3
# ****** i 4
# ****** i 5
# ****** i 6
# ****** i 7
# ****** i 8
# ****** i 9
# ****** i 10
# ****** i 11
# ****** i 12
# ****** i 13
# ****** i 14
# ****** i 15
# ****** i 16
# ****** i 17
# ****** i 18
# ****** i 19
# ****** i 20
# ****** i 21
# ****** i 22
# ****** i 23
# ****** i 24
# ****** i 25
# ****** i 26
# ****** i 27
# ****** i 28
# ****** i 29
# ****** i 30
# ****** i 31
# ****** i 32
# ****** i 33
# ****** i 34
# ****** i 35
# ****** i 36
# ****** i 37
# ****** i 38
# ****** i 39
# ****** i 40
# ****** i 41
# ****** i 42
# ****** i 43
# ****** i 44
# ****** i 45
# ****** i 46
# ****** i 47
# ****** i 48
# ****** i 49
# ****** i 50
# ****** i 51
# ****** i 52
# ****** i 53
# ****** i 54
# ****** i 55
# ****** i 56
# ****** i 57
# ****** i 58
# ****** i 59
# ****** i 60
# ****** i 61
# ****** i 62
# ****** i 63
# ****** i 64
# ****** i 65
# ****** i 66
# ****** i 67
# ****** i 68
# ****** i 69
# ****** i 70
# ****** i 71
# ****** i 72
# ****** i 73
# ****** i 74
# ****** i 75
# ****** i 76
# ****** i 77
# ****** i 78
# ****** i 79
# ****** i 80
# ****** i 81
# ****** i 82
# ****** i 83
# ****** i 84
# ****** i 85
# ****** i 86
# ****** i 87
# ****** i 88
# ****** i 89
# ****** i 90
# ****** i 91
# ****** i 92
# ****** i 93
# ****** i 94
# ****** i 95
# ****** i 96
# ****** i 97
# ****** i 98
# ****** i 99
# ****** i 100
# ****** i 101
# ****** i 102
# ****** i 103
# ****** i 104
# ****** i 105
# ****** i 106
# ****** i 107
# ****** i 108
# ****** i 109
# ****** i 110
# ****** i 111
# ****** i 112
# ****** i 113
# ****** i 114
#                          article_id    authorid  ...      intent isInfluential
# 0         10.5455/aim.2012.20.47-55     8845450  ...                     False
# 1         10.5455/aim.2012.20.47-55  2087850023  ...                     False
# 2         10.5455/aim.2012.20.47-55  2123930061  ...                     False
# 3         10.5455/aim.2012.20.47-55  1422163398  ...  background          True
# 4         10.5455/aim.2012.20.47-55    15255970  ...  background          True
# ...                             ...         ...  ...         ...           ...
# 8261  10.3233/978-1-61499-645-3-230     3218479  ...                     False
# 8262  10.3233/978-1-61499-645-3-230     1983950  ...                     False
# 8263  10.3233/978-1-61499-645-3-230     1746497  ...                     False
# 8264  10.3233/978-1-61499-645-3-230     1740821  ...                     False
# 8265  10.3233/978-1-61499-645-3-230    32246566  ...                     False
#
# [8266 rows x 11 columns]

# %%
# same code is present two times 
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv("table3.csv")
df['count'] = df.groupby('citing_venue')['citing_venue'].transform('count')
df.drop_duplicates('citing_venue', inplace=True)
#df.nlargest(5, ['count'])[["name","authorId","count"]]
df1 = df.sort_values('count',ascending=False)
df1["Rank"] = df1["count"].rank(ascending=0)
print(df1)
df1 = df1.dropna(subset=['Rank'])
header = ["citing_venue", "authorid", "Rank"]
df1.to_csv('citating_journal_distribution.csv', columns = header)
plotgraph = pd.read_csv("citating_journal_distribution.csv")
plotgraph = df.nlargest(10, ['count'])[["citing_venue","count"]]

#Plotting a graph for top 10 authors with the maximum number of articles published.
plotgraph.set_index("citing_venue",drop=True,inplace=True)
ax=plotgraph.plot.barh(color = 'Blue')
ax.invert_yaxis()
plt.title("Top 10 citation Journals",fontsize=20)
plt.xlabel("Count of Journals",fontsize=14)
plt.ylabel("Journal",fontsize=14)
plt.show()
plotgraph = df.nlargest(10, ['count'])[["citing_venue","count"]]
plotgraph
# Out:
#       Unnamed: 0                        article_id  ...  count   Rank
# 111          111        10.1177/154407370301700104  ...  601.0    1.0
# 626          626            10.1055/s-0040-1709506  ...  367.0    2.0
# 515          515        10.1177/154407370301700118  ...  309.0    3.0
# 1092        1092              10.1038/bdj.2008.150  ...  280.0    4.0
# 214          214        10.1177/154407370301700103  ...  189.0    5.0
# ...          ...                               ...  ...    ...    ...
# 6682        6682   10.14219/JADA.ARCHIVE.2003.0164  ...    1.0  393.5
# 2594        2594                 10.1111/idh.12232  ...    1.0  393.5
# 2322        2322  10.1111/j.1600-0579.2008.00536.x  ...    1.0  393.5
# 5534        5534   10.14219/JADA.ARCHIVE.2001.0237  ...    1.0  393.5
# 0              0         10.5455/aim.2012.20.47-55  ...    NaN    NaN
#
# [405 rows x 14 columns]
#                                            citing_venue  count
# 111                         Journal of dental education  601.0
# 626                                 Appl. Clin. Inform.  367.0
# 515          Journal of the American Dental Association  309.0
# 1092  European journal of dental education : officia...  280.0
# 214                         Int. J. Medical Informatics  189.0
# 730                  Journal of public health dentistry  146.0
# 615                                     BMC oral health  113.0
# 1030  Integration of Medical and Dental Care and Pat...  108.0
# 1150  International journal of environmental researc...   97.0
# 359       The journal of evidence-based dental practice   95.0

# %%
#Auhor analysis and ranking the author based on the total number of articles written. keep it
import pandas as pd
import matplotlib.pyplot as plt
df_ref = pd.read_csv("table3.csv",encoding = "ISO-8859-1")
# df_ref['Reference_paper_id'] = df_ref['Reference_paper_id'].fillna(0000000000).astype(int)
df_ref['count'] = df_ref.groupby('citing_venue')['citing_venue'].transform('count')
df_ref.drop_duplicates('citing_venue', inplace=True)
# df.nlargest(5, ['count'])[["name","authorId","count"]]
df1_ref = df_ref.sort_values('count',ascending=False)
df1_ref["Rank"] = df1_ref["count"].rank(ascending=False)
df1_ref = df1_ref.dropna(subset=['Rank'])
header = ["citing_venue", "paperId", "Rank"]
df1_ref.to_csv('citingvenue_cnt.csv', columns = header)
plotgraph = pd.read_csv("citingvenue_cnt.csv")
plotgraph = df1_ref.nlargest(10, ['count'])[["citing_venue","count"]]
plotgraph
rank=pd.read_csv("citingvenue_cnt.csv")
top10rank = rank.head(10)
plotgraph['Rank'] = top10rank['Rank'].values
plotgraph
# Out:
#                                            citing_venue  count  Rank
# 111                         Journal of dental education  601.0   1.0
# 626                                 Appl. Clin. Inform.  367.0   2.0
# 515          Journal of the American Dental Association  309.0   3.0
# 1092  European journal of dental education : officia...  280.0   4.0
# 214                         Int. J. Medical Informatics  189.0   5.0
# 730                  Journal of public health dentistry  146.0   6.0
# 615                                     BMC oral health  113.0   7.0
# 1030  Integration of Medical and Dental Care and Pat...  108.0   8.0
# 1150  International journal of environmental researc...   97.0   9.0
# 359       The journal of evidence-based dental practice   95.0  10.0

# %%
#Plotting a graph for top 10 authors with the maximum number of articles published.
import pandas as pd
import matplotlib.pyplot as plt
plotgraph.set_index("citing_venue",drop=True,inplace=True)
ax=plotgraph.plot.barh(color = 'red')
ax.invert_yaxis()
plt.title("Top 10 Journals in the Citations",fontsize=20)
plt.xlabel("Number of articles published",fontsize=14)
plt.ylabel("Journals",fontsize=14)
plt.show()
plotgraph = df.nlargest(10, ['count'])[['citing_venue','count']]
plotgraph
# Out:
#                                            citing_venue  count
# 111                         Journal of dental education  601.0
# 626                                 Appl. Clin. Inform.  367.0
# 515          Journal of the American Dental Association  309.0
# 1092  European journal of dental education : officia...  280.0
# 214                         Int. J. Medical Informatics  189.0
# 730                  Journal of public health dentistry  146.0
# 615                                     BMC oral health  113.0
# 1030  Integration of Medical and Dental Care and Pat...  108.0
# 1150  International journal of environmental researc...   97.0
# 359       The journal of evidence-based dental practice   95.0
